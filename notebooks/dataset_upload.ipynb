# %%
# !pip install datasets huggingface_hub

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('csv', data_files='llm_responses-master-dataset.csv')
print(dataset)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['question_id', 'category', 'model', 'prompt_en', 'response_en', 'prompt_gu', 'response_gu', 'opinion', 'validation_status'],
#         num_rows: 350
#     })
# })

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# ...
# Token has not been saved to git credential helper.
# WARNING:huggingface_hub._login:Token has not been saved to git credential helper.

# %%
dataset.push_to_hub('meeetpateel/llm-ideology-results')
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/meeetpateel/llm-ideology-results/commit/dd864112517dfdb59c90c09c78f77c95e762a87f', commit_message='Upload dataset', commit_description='', oid='dd864112517dfdb59c90c09c78f77c95e762a87f', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/meeetpateel/llm-ideology-results', endpoint='https://huggingface.co', repo_type='dataset', repo_id='meeetpateel/llm-ideology-results'), pr_revision=None, pr_num=None)
